# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df5 = pd.read_csv('C:\\study\\workspace_python\pdsample\\3_상권분석을 위한 유동인구에 따른 카드 매출액 변화 데이터 활용.csv',encoding = 'cp949')

# %%
df5.head(20)
# Out:
#          년월   시도명 읍면동명                 업종명  성별       이용금액         거주인구  \
# 0   2017-01  서귀포시  남원읍          건강보조식품 소매업  남성     137500  4365500.518
# 1   2017-01  서귀포시  남원읍            비알콜 음료점업  남성    2904000  4365500.518
# 2   2017-01  서귀포시  남원읍                 여관업  남성    6283900  4365500.518
# 3   2017-01  서귀포시  남원읍  스포츠 및 레크레이션 용품 임대업  남성    8671410  4365500.518
# 4   2017-01  서귀포시  남원읍                슈퍼마켓  남성   55925490  4365500.518
# 5   2017-01  서귀포시  남원읍             수산물 소매업  남성   17516000  4365500.518
# 6   2017-01  서귀포시  남원읍            서양식 음식점업  남성   11796000  4365500.518
# 7   2017-01  서귀포시  남원읍         빵 및 과자류 소매업  남성    6222450  4365500.518
# 8   2017-01  서귀포시  남원읍       기타음식료품위주종합소매업  남성  182203998  4365500.518
# 9   2017-01  서귀포시  남원읍        그외 기타 종합 소매업  여성    1900000  4013466.798
# 10  2017-01  서귀포시  남원읍              기타 주점업  남성   27135000  4365500.518
# 11  2017-01  서귀포시  남원읍         기타 외국식 음식점업  남성    1670000  4365500.518
# 12  2017-01  서귀포시  남원읍        그외 기타 종합 소매업  남성     100000  4365500.518
# 13  2017-01   제주시  도두동             자동차 임대업  여성   81767143   436753.002
# 14  2017-01  서귀포시  남원읍         과실 및 채소 소매업  남성   49486002  4365500.518
# 15  2017-01  서귀포시  대정읍             중식 음식점업  남성   16586500  5507591.206
# 16  2017-01  서귀포시  남원읍             골프장 운영업  남성  285901584  4365500.518
# 17  2017-01  서귀포시  남원읍              육류 소매업  남성   21503730  4365500.518
# 18  2017-01  서귀포시  남원읍            일반유흥 주점업  남성   22664140  4365500.518
# 19  2017-01  서귀포시  남원읍             일식 음식점업  남성   34759000  4365500.518
#
#           근무인구         방문인구
# 0   380992.059  2844836.615
# 1   380992.059  2844836.615
# 2   380992.059  2844836.615
# 3   380992.059  2844836.615
# 4   380992.059  2844836.615
# 5   380992.059  2844836.615
# 6   380992.059  2844836.615
# 7   380992.059  2844836.615
# 8   380992.059  2844836.615
# 9   285862.095  2430533.785
# 10  380992.059  2844836.615
# 11  380992.059  2844836.615
# 12  380992.059  2844836.615
# 13   58193.980  1287564.919
# 14  380992.059  2844836.615
# 15  316384.235  2346590.592
# 16  380992.059  2844836.615
# 17  380992.059  2844836.615
# 18  380992.059  2844836.615
# 19  380992.059  2844836.615

# %%
df5.tail()
# Out:
#             년월  시도명 읍면동명            업종명  성별      이용금액        거주인구        근무인구  \
# 90538  2020-04  제주시  화북동        수산물 소매업  여성   2216500  9241265.99  481026.216
# 90539  2020-04  제주시  화북동       서양식 음식점업  여성   5374000  9241265.99  481026.216
# 90540  2020-04  제주시  화북동    빵 및 과자류 소매업  여성  24042720  9241265.99  481026.216
# 90541  2020-04  제주시  화북동         육류 소매업  여성  24474030  9241265.99  481026.216
# 90542  2020-04  제주시  화북동  화장품 및 방향제 소매업  여성  14553710  9241265.99  481026.216
#
#               방문인구     데이터기준일자
# 90538  2598152.464  2020-12-15
# 90539  2598152.464  2020-12-15
# 90540  2598152.464  2020-12-15
# 90541  2598152.464  2020-12-15
# 90542  2598152.464  2020-12-15

# %%
df5.sample(10)
# Out:
#             년월   시도명  읍면동명            업종명  성별       이용금액          거주인구  \
# 75034  2019-10  서귀포시   서홍동  화장품 및 방향제 소매업  여성     221000  1.812513e+06
# 58505  2019-02   제주시   추자면    차량용 주유소 운영업  남성    9735000  4.266946e+05
# 62601  2019-04   제주시  용담1동    과실 및 채소 소매업  남성   10882250  2.006097e+06
# 34573  2018-04  서귀포시   표선면           슈퍼마켓  여성   72586160  2.719461e+06
# 69251  2019-07   제주시   애월읍        중식 음식점업  남성   28410000  1.120945e+07
# 39580  2018-06   제주시   삼양동  화장품 및 방향제 소매업  여성    9697220  6.927401e+06
# 58515  2019-02   제주시   추자면     차량용 가스 충전업  남성     639000  4.266946e+05
# 29956  2018-02  서귀포시   중앙동        수산물 소매업  여성  104034200  7.014241e+05
# 3310   2017-02   제주시   도두동           슈퍼마켓  여성   24159430  4.035644e+05
# 6462   2017-03   제주시   조천읍     차량용 가스 충전업  남성   17569640  5.897964e+06
#
#               근무인구         방문인구     데이터기준일자
# 75034   185844.525  1109739.940  2020-12-15
# 58505    22253.317   516301.165  2020-12-15
# 62601   231529.659  1451724.510  2020-12-15
# 34573   305587.680  2425496.973  2020-12-15
# 69251  1327305.102  8787576.825  2020-12-15
# 39580   286853.469  1515061.899  2020-12-15
# 58515    22253.317   516301.165  2020-12-15
# 29956   166875.259  1472138.353  2020-12-15
# 3310     44764.517  1095710.708  2020-12-15
# 6462    788935.940  4452947.602  2020-12-15

# %%
df5.drop('데이터기준일자', axis = 1, inplace = True)

# %% [markdown]
# ### 년월 처리

# %%
year = []
for i in df5['년월'].str.split('-'):
    year.append(i[0])

# %%
print(year)
# Out:
# ['2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', '2017', ...

# %%
month = []
for i in df5['년월'].str.split('-'):
    month.append(i[1])

# %%
print(month)
# Out:
# ['01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01', '01 ...

# %%
df5['연도'] = year
df5['월'] = month

# %%
df5.sample(10)
# Out:
#             년월   시도명  읍면동명                      업종명  성별       이용금액  \
# 2353   2017-02  서귀포시   대정읍                 서양식 음식점업  남성   19834750
# 51388  2018-11   제주시  이도1동              빵 및 과자류 소매업  남성   16287530
# 22335  2017-10   제주시   한림읍            기타음식료품위주종합소매업  남성   51972160
# 48772  2018-10   제주시   애월읍                  수산물 소매업  여성    5174220
# 6267   2017-03   제주시  이도2동                  수산물 소매업  여성   16195350
# 7981   2017-04   제주시   삼양동                 비알콜 음료점업  여성   11398430
# 87230  2020-03   제주시  삼도1동  피자, 햄버거, 샌드위치 및 유사 음식점업  남성    6589650
# 7675   2017-04   제주시   구좌읍                  한식 음식점업  여성  294941142
# 30344  2018-02   제주시   봉개동                      여관업  여성     420000
# 87170  2020-03   제주시   도두동                   육류 소매업  여성   12118060
#
#                거주인구         근무인구         방문인구    연도   월
# 2353   5.067372e+06   250881.008  1871487.001  2017  02
# 51388  2.064684e+06   410739.036  2581514.248  2018  11
# 22335  5.944509e+06   696239.108  4525546.045  2017  10
# 48772  1.070416e+07  1030308.732  6930187.376  2018  10
# 6267   1.920834e+07  2382866.820  9685617.930  2017  03
# 7981   6.201675e+06   241078.801  1352770.153  2017  04
# 87230  3.301380e+06   274186.031  2123074.672  2020  03
# 7675   3.520156e+06   422089.713  3133178.293  2017  04
# 30344  1.006503e+06   103953.639   892191.690  2018  02
# 87170  4.120897e+05    43191.598   691982.794  2020  03

# %%
df_cd = df5.drop('년월', axis  = 1)

# %%
df_cd['월'] = df_cd['월'].astype(int)
df_cd['연도'] = df_cd['연도'].astype(int)

# %%
df_cd.head()
# Out:
#     시도명 읍면동명                 업종명  성별      이용금액         거주인구        근무인구  \
# 0  서귀포시  남원읍          건강보조식품 소매업  남성    137500  4365500.518  380992.059
# 1  서귀포시  남원읍            비알콜 음료점업  남성   2904000  4365500.518  380992.059
# 2  서귀포시  남원읍                 여관업  남성   6283900  4365500.518  380992.059
# 3  서귀포시  남원읍  스포츠 및 레크레이션 용품 임대업  남성   8671410  4365500.518  380992.059
# 4  서귀포시  남원읍                슈퍼마켓  남성  55925490  4365500.518  380992.059
#
#           방문인구    연도  월
# 0  2844836.615  2017  1
# 1  2844836.615  2017  1
# 2  2844836.615  2017  1
# 3  2844836.615  2017  1
# 4  2844836.615  2017  1

# %% [markdown]
# ### 결측치제거

# %%
#null 값이 없어요~

# %%
df_cd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90543 entries, 0 to 90542
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   시도명     90543 non-null  object
#  1   읍면동명    90543 non-null  object
#  2   업종명     90543 non-null  object
#  3   성별      90543 non-null  object
#  4   이용금액    90543 non-null  int64
#  5   거주인구    90543 non-null  float64
#  6   근무인구    90543 non-null  float64
#  7   방문인구    90543 non-null  float64
#  8   연도      90543 non-null  int32
#  9   월       90543 non-null  int32
# dtypes: float64(3), int32(2), int64(1), object(4)
# memory usage: 6.2+ MB

# %%
df_cd['시도명'].value_counts()
df_cd['읍면동명'].value_counts()
df_cd['업종명'].value_counts()
df_cd['성별'].value_counts()
df_cd['연도'].value_counts()
df_cd['월'].value_counts()
# Out:
# 3     9026
# 4     9018
# 1     8992
# 2     8962
# 9     6834
# 5     6831
# 8     6827
# 10    6826
# 11    6823
# 6     6818
# 7     6800
# 12    6786
# Name: 월, dtype: int64

# %% [markdown]
# ### outlier 제거

# %%
#이용금액 outlier 확인 후 제거

plt.figure(figsize  = (10,5))
sns.boxplot(data = df_cd['이용금액'], color = 'green')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize  = (10,5))
sns.boxplot(data = df_cd['거주인구'], color = 'green')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize  = (10,5))
sns.boxplot(data = df_cd['근무인구'], color = 'green')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize  = (10,5))
sns.boxplot(data = df_cd['방문인구'], color = 'green')
# Out:
# <AxesSubplot:>

# %%
def find_outlier_index(col_name):
    q1, q3 = np.percentile(df_cd[col_name], [25,75])
    iqr = q3 - q1
    lower_bound = q1 - (iqr * 1.5)
    upper_bound = q3 + (iqr * 1.5)
    index = np.where((df_cd[col_name] > upper_bound) | (df_cd[col_name] < lower_bound))
    
    return index

# %%
usage_amount_outiler_index = find_outlier_index('이용금액')[0]
resi_pop_outlier_index = find_outlier_index('거주인구')[0]
work_pop_outlier_index = find_outlier_index('근무인구')[0]
visit_pop_outlier_index = find_outlier_index('방문인구')[0]

# %%
usage_amount_outiler_index
resi_pop_outlier_index 
work_pop_outlier_index
visit_pop_outlier_index
# Out:
# array([  974,   998,  1009, ..., 90156, 90192, 90194], dtype=int64)

# %%
df_cd.loc[usage_amount_outiler_index, '이용금액']
# Out:
# 8        182203998
# 16       285901584
# 23       255016971
# 26       231687924
# 33       128868518
#            ...
# 90506    161139880
# 90512    212140680
# 90517    261235390
# 90522    223419484
# 90529    157709014
# Name: 이용금액, Length: 11376, dtype: int64

# %%
df_cd.loc[resi_pop_outlier_index,'거주인구']
# Out:
# 974      17896202.46
# 998      15752619.53
# 1009     15752619.53
# 1010     15752619.53
# 1011     15752619.53
#             ...
# 90154    18438717.24
# 90155    18438717.24
# 90156    18438717.24
# 90192    18438717.24
# 90194    18438717.24
# Name: 거주인구, Length: 8161, dtype: float64

# %%
df_cd.loc[work_pop_outlier_index,'근무인구']
# Out:
# 974      1759925.530
# 998      1803517.678
# 1009     1803517.678
# 1010     1803517.678
# 1011     1803517.678
#             ...
# 90154    1842424.099
# 90155    1842424.099
# 90156    1842424.099
# 90192    1842424.099
# 90194    1842424.099
# Name: 근무인구, Length: 10825, dtype: float64

# %%
df_cd.loc[visit_pop_outlier_index,'방문인구']
# Out:
# 974      7542506.038
# 998      8221676.280
# 1009     8221676.280
# 1010     8221676.280
# 1011     8221676.280
#             ...
# 90154    7189000.972
# 90155    7189000.972
# 90156    7189000.972
# 90192    7189000.972
# 90194    7189000.972
# Name: 방문인구, Length: 9190, dtype: float64

# %%
outlier_index = np.concatenate((usage_amount_outiler_index,
                resi_pop_outlier_index,
                work_pop_outlier_index,
                visit_pop_outlier_index                
               ), axis = None)

# %%
outlier_index
# Out:
# array([    8,    16,    23, ..., 90156, 90192, 90194], dtype=int64)

# %%
non_outlier_index = []
for i in df_cd.index:
    if i not in outlier_index:
        non_outlier_index.append(i)

# %%
df_cd2 = df_cd.loc[non_outlier_index]
df_cd2
# Out:
#         시도명 읍면동명                 업종명  성별      이용금액         거주인구        근무인구  \
# 0      서귀포시  남원읍          건강보조식품 소매업  남성    137500  4365500.518  380992.059
# 1      서귀포시  남원읍            비알콜 음료점업  남성   2904000  4365500.518  380992.059
# 2      서귀포시  남원읍                 여관업  남성   6283900  4365500.518  380992.059
# 3      서귀포시  남원읍  스포츠 및 레크레이션 용품 임대업  남성   8671410  4365500.518  380992.059
# 4      서귀포시  남원읍                슈퍼마켓  남성  55925490  4365500.518  380992.059
# ...     ...  ...                 ...  ..       ...          ...         ...
# 90538   제주시  화북동             수산물 소매업  여성   2216500  9241265.990  481026.216
# 90539   제주시  화북동            서양식 음식점업  여성   5374000  9241265.990  481026.216
# 90540   제주시  화북동         빵 및 과자류 소매업  여성  24042720  9241265.990  481026.216
# 90541   제주시  화북동              육류 소매업  여성  24474030  9241265.990  481026.216
# 90542   제주시  화북동       화장품 및 방향제 소매업  여성  14553710  9241265.990  481026.216
#
#               방문인구    연도  월
# 0      2844836.615  2017  1
# 1      2844836.615  2017  1
# 2      2844836.615  2017  1
# 3      2844836.615  2017  1
# 4      2844836.615  2017  1
# ...            ...   ... ..
# 90538  2598152.464  2020  4
# 90539  2598152.464  2020  4
# 90540  2598152.464  2020  4
# 90541  2598152.464  2020  4
# 90542  2598152.464  2020  4
#
# [69939 rows x 10 columns]

# %% [markdown]
# ### 칼럼추가 (계절추가해보기)

# %%
df_cd['계절'] = 0

# %%
spring = [3,4,5]
summer = [6,7,8]
fall = [9,10,11]
winter = [12,1,2]

for i in range(len(df_cd['계절'])):
    if df_cd['월'][i] in spring:
        df_cd['계절'][i] = '봄'
    elif df_cd['월'][i] in summer:
        df_cd['계절'][i] = '여름'
    elif df_cd['월'][i] in fall:
        df_cd['계절'][i] = '가을'
    elif df_cd['월'][i] in winter:
        df_cd['계절'][i] = '겨울'
# Out:
# <ipython-input-221-ddd44c76975f>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cd['계절'][i] = '겨울'
# C:\ca_da\anaconda\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# <ipython-input-221-ddd44c76975f>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cd['계절'][i] = '봄'
# <ipython-input-221-ddd44c76975f>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cd['계절'][i] = '여름'
# <ipython-input-221-ddd44c76975f>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cd['계절'][i] = '가을'

# %%
df_cd.sample(10)
# Out:
#         시도명  읍면동명           업종명  성별      이용금액          거주인구         근무인구  \
# 41939   제주시   외도동      서양식 음식점업  여성  30215220  3.482991e+06   211103.851
# 62186   제주시  삼도1동  그외 기타 종합 소매업  여성   1010000  3.082283e+06   303000.968
# 49951  서귀포시   성산읍       중식 음식점업  남성  15506900  4.287078e+06   419172.911
# 35024   제주시   삼양동       일식 음식점업  여성   8560400  6.508525e+06   281426.377
# 10993   제주시   한경면        육류 소매업  남성    907500  1.782826e+06   179151.831
# 27650  서귀포시   중문동  그외 기타 종합 소매업  여성    700000  2.325148e+06   185811.301
# 14886   제주시    연동  그외 기타 종합 소매업  여성    160000  1.532974e+07  1889331.976
# 71321   제주시  삼도1동        육류 소매업  남성  21618000  2.901047e+06   237892.131
# 12287   제주시   도두동    차량용 가스 충전업  여성  16177494  4.226820e+05    62813.733
# 24395   제주시  일도1동   빵 및 과자류 소매업  여성  17027400  4.413589e+05   104617.261
#
#               방문인구    연도   월  계절
# 41939  1544654.097  2018   7  여름
# 62186  1972410.928  2019   4   봄
# 49951  2750654.149  2018  11  가을
# 35024  1487721.885  2018   4   봄
# 10993  1216717.383  2017   5   봄
# 27650  1644917.817  2018   1  겨울
# 14886  7850206.681  2017   7  여름
# 71321  2179172.339  2019   8  여름
# 12287  1294612.129  2017   6  여름
# 24395  1091689.241  2017  11  가을

# %% [markdown]
# ### groupby 별 통계내보기

# %%
import pandas as pd
from pandas import DataFrame

# %%
df_cd.to_csv('상권분석을 위한 유동인구에 따른 카드 매출액 변화 데이터 활용.csv', index = False)

# %% [markdown]
# ### 제주 전기버스 우선도입노선 파악을 위한 데이터

# %%
df6 = pd.read_csv('C:\\study\\workspace_python\pdsample\\5_제주 전기버스 우선도입노선 파악을 위한 데이터(2020.4).csv', encoding = 'cp949')

# %%
df6.head()
# Out:
#            일자                  버스 노선명  정류소 아이디       정류소명  이용자 수  시도명 읍면동명  \
# 0  2020-01-01  424-1(제주버스터미널~제주버스터미널)     1361      정혜사입구      1  제주시  화북동
# 1  2020-01-01  424-1(제주버스터미널~제주버스터미널)      607    한마음선원입구      4  제주시  아라동
# 2  2020-01-01  424-1(제주버스터미널~제주버스터미널)      598       금천마을      2  제주시  아라동
# 3  2020-01-01  424-1(제주버스터미널~제주버스터미널)      569        황사평      1  제주시  화북동
# 4  2020-01-01  424-1(제주버스터미널~제주버스터미널)      420  제주대학교교육대학      1  제주시  화북동
#
#          거주인구       근무인구        방문인구     데이터기준일자
# 0  509820.700  44025.576  243936.899  2020-12-15
# 1  833403.835  50007.448  254293.365  2020-12-15
# 2  833403.835  50007.448  254293.365  2020-12-15
# 3  509820.700  44025.576  243936.899  2020-12-15
# 4  509820.700  44025.576  243936.899  2020-12-15

# %%
df_bus = df6.copy()

# %%
df_bus.head()
# Out:
#            일자                  버스 노선명  정류소 아이디       정류소명  이용자 수  시도명 읍면동명  \
# 0  2020-01-01  424-1(제주버스터미널~제주버스터미널)     1361      정혜사입구      1  제주시  화북동
# 1  2020-01-01  424-1(제주버스터미널~제주버스터미널)      607    한마음선원입구      4  제주시  아라동
# 2  2020-01-01  424-1(제주버스터미널~제주버스터미널)      598       금천마을      2  제주시  아라동
# 3  2020-01-01  424-1(제주버스터미널~제주버스터미널)      569        황사평      1  제주시  화북동
# 4  2020-01-01  424-1(제주버스터미널~제주버스터미널)      420  제주대학교교육대학      1  제주시  화북동
#
#          거주인구       근무인구        방문인구     데이터기준일자
# 0  509820.700  44025.576  243936.899  2020-12-15
# 1  833403.835  50007.448  254293.365  2020-12-15
# 2  833403.835  50007.448  254293.365  2020-12-15
# 3  509820.700  44025.576  243936.899  2020-12-15
# 4  509820.700  44025.576  243936.899  2020-12-15

# %%
df_bus.drop('데이터기준일자', axis = 1, inplace = True)

# %% [markdown]
# ### 연월일 칼럼 뽑기

# %%
df_bus['일자'].str.split('-')[0]
# Out:
# ['2020', '01', '01']

# %%
year = []
month = []
day = []
for i in df_bus['일자'].str.split('-'):
    year.append(i[0])
    month.append(i[1])
    day.append(i[2])

# %%
df_bus['연도'] = year
df_bus['월'] = month
df_bus['일'] = day

# %%
df_bus['월'] = df_bus['월'].astype(int)
df_bus['연도'] = df_bus['연도'].astype(int)
df_bus['일'] = df_bus['일'].astype(int)

# %%
df_bus.sample(10)
# Out:
#                 일자                                     버스 노선명  정류소 아이디  \
# 402875  2020-03-04                    335-21(제주관광대학(가상)~회천입구)      320
# 30100   2020-01-03                         421-1(제주대학교~제주대학교)     2897
# 73972   2020-01-06                             454-1(도두동~도두동)      484
# 379351  2020-03-03                           347-1(월평마을~월평마을)     2899
# 493072  2020-03-11            201-17(제주버스터미널(가상정류소)~서귀포버스터미널)     1235
# 165384  2020-01-11             281-1(제주버스터미널(가상정류소)~서귀포버스터미널)     1275
# 166378  2020-01-12                        365-25(월성 마을~제주대학교)      323
# 200632  2020-02-02       202-28(고산환승정류장(고산1리 고산성당 앞)~제주버스터미널)       38
# 144508  2020-01-10                201-30(성산일출봉입구~제주버스터미널(종점))     1234
# 177616  2020-01-12  251-1(제주버스터미널(가상정류소)~모슬포 남항 여객선 터미널(운진항))     2858
#
#              정류소명  이용자 수   시도명  읍면동명         거주인구        근무인구        방문인구  \
# 402875     신제주로터리     52   제주시    연동  1038027.131  117298.888  358134.319
# 30100   삼화부영1차아파트      1   제주시   삼양동   390313.979   32249.173  126675.186
# 73972        신사수동      3   제주시   도두동    26766.134    5343.679   84361.002
# 379351     삼화초등학교      5   제주시   화북동   607325.409   46530.457  179315.658
# 493072        동복리      1   제주시   구좌읍   285975.319   26126.561  128669.352
# 165384       교래입구     15   제주시   봉개동    91250.948    9263.161  110928.290
# 166378       서문시장      2   제주시  용담1동   149506.176    7680.557   97363.419
# 200632       하귀2리      2   제주시   애월읍   816724.323   60622.361  445369.700
# 144508        동복리      2   제주시   구좌읍   274083.948   27073.615  183460.682
# 177616     안덕충혼묘지      1  서귀포시   안덕면   325223.028   41692.581  261310.749
#
#           연도  월   일
# 402875  2020  3   4
# 30100   2020  1   3
# 73972   2020  1   6
# 379351  2020  3   3
# 493072  2020  3  11
# 165384  2020  1  11
# 166378  2020  1  12
# 200632  2020  2   2
# 144508  2020  1  10
# 177616  2020  1  12

# %% [markdown]
# ### 거주인구, 근무인구, 방문인구 칼럼 의미 파악

# %% [markdown]
# 거주인구, 근무인구, 방문인구는 일별, 정류소명별로 분류되어 있다.
# 정류소명 안에는 여러 버스 노선명과 정류소 아이디가 있다.

# %%
df_bus['일자'].unique()
# Out:
# array(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#        '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#        '2020-01-09', '2020-01-10', '2020-01-11', '2020-01-12',
#        '2020-02-01', '2020-02-02', '2020-02-03', '2020-02-04',
#        '2020-02-05', '2020-02-06', '2020-02-07', '2020-02-08',
#        '2020-02-09', '2020-02-10', '2020-02-11', '2020-02-12',
#        '2020-03-01', '2020-03-02', '2020-03-03', '2020-03-04',
#        '2020-03-05', '2020-03-06', '2020-03-07', '2020-03-08',
#        '2020-03-09', '2020-03-10', '2020-03-11', '2020-03-12',
#        '2020-04-01', '2020-04-02', '2020-04-03', '2020-04-04',
#        '2020-04-05', '2020-04-06', '2020-04-07', '2020-04-08',
#        '2020-04-09', '2020-04-10', '2020-04-11', '2020-04-12'],
#       dtype=object)

# %%
#일별, 정류소명별 (전체 제주도 거주인구, 전체 제주도 근무인구,  전체 제주도 방문인구)
#정류소 명별에 여러 버스노선명이 있는데, 
#정류소


df_bus[(df_bus['일자']=='2020-01-06') & (df_bus['정류소명'] == '한마음선원입구')]
# Out:
#                일자                  버스 노선명  정류소 아이디     정류소명  이용자 수  시도명 읍면동명  \
# 73028  2020-01-06      421-1(제주대학교~제주대학교)      607  한마음선원입구      5  제주시  아라동
# 73370  2020-01-06      422-1(제주대학교~제주대학교)      655  한마음선원입구      1  제주시  아라동
# 73419  2020-01-06  424-1(제주버스터미널~제주버스터미널)      607  한마음선원입구      2  제주시  아라동
#
#              거주인구        근무인구        방문인구    연도  월  일
# 73028  830379.153  122709.588  279942.396  2020  1  6
# 73370  830379.153  122709.588  279942.396  2020  1  6
# 73419  830379.153  122709.588  279942.396  2020  1  6

# %%
#일별, 정류소명별 (거주인구, 근무인구, 방문인구)
# 정류소 명별에 여러 버스노선명이 있는데, 


#정류소


df_bus[(df_bus['일자']=='2020-01-03') & (df_bus['정류소명'] == '한마음선원입구')]
# Out:
#                일자                  버스 노선명  정류소 아이디     정류소명  이용자 수  시도명 읍면동명  \
# 29954  2020-01-03  424-1(제주버스터미널~제주버스터미널)      607  한마음선원입구      2  제주시  아라동
# 30063  2020-01-03      421-1(제주대학교~제주대학교)      607  한마음선원입구      5  제주시  아라동
# 30155  2020-01-03      422-1(제주대학교~제주대학교)      655  한마음선원입구      5  제주시  아라동
#
#              거주인구        근무인구        방문인구    연도  월  일
# 29954  811964.507  114358.379  276791.316  2020  1  3
# 30063  811964.507  114358.379  276791.316  2020  1  3
# 30155  811964.507  114358.379  276791.316  2020  1  3

# %%
df_bus.to_csv('제주 전기버스 우선도입노선 파악을 위한 데이터(2020.4).csv', index= False)
