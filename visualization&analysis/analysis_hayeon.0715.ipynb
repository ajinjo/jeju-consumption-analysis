# %%
from IPython.display import Image
 
Image("제주유동.png")

# %% [markdown]
# ### 제주유동인구는 328만명이라 한다.

# %%
Image("논문.png")

# %% [markdown]
# ### 논문에서도 7월 한달간의 데이터로 분석한 걸 보면,                               보통 한달이상의 유동인구 데이터는 찾기 힘든듯 하다.

# %% [markdown]
#  ---------
#
#
# #0715
#
# 제주 POI 전처리는 끝난 상태.
#
# 유동인구 데이터는 시간대별로 시계열이 긴 데이터로 찾는 중.
# 현재 유동인구 분석 적용방법에 대해 찾아보고 있음
#
#
# 한달이 보통 최대인 것 같아서
# 우선 내일 공공데이터포털에서 다운받은 시간대별, 성연령별 유동인구 데이터들로 시각화가 가능한지 해보려함.
